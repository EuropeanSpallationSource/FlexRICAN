# %%
import subprocess

# %%
process = subprocess.Popen(
    ["python", "scripts/Scenario_1_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="")

process.wait()
# Out:
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# Data loaded from ./data/France_dataset.csv , Starting Optimization Scenario 1 for France
# Data loaded from ./data/Czech_dataset.csv , Starting Optimization Scenario 1 for Czech
# 0

# %%
process = subprocess.Popen(
    ["python", "scripts/Scenario_2_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="")

process.wait()

# %%
process = subprocess.Popen(
    ["python", "scripts/Scenario_3_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout: 
    print(line, end="")

process.wait()

# %%
process = subprocess.Popen(
    ["python", "scripts/Scenario_4_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="")

process.wait()
