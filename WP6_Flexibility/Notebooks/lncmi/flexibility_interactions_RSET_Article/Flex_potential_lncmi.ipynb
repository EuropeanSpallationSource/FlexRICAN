# %%
import subprocess

# %%
process = subprocess.Popen(
    ["python", "Scenario_1_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="")

process.wait()
# Out:
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# Data loaded from ./data/France_dataset.csv , Starting Optimization Scenario 1 for France
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# Creating the pv.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\energy_units.py:1429: UserWarning: The solution may be imaginary as nb_unit is continuous
#   warnings.warn(
# Creating the conso.
# Creating the grid_imp.
# Creating the grid_exp.
# Creating the elec_node.
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\27473ca41d764c8b92fd0a7d869f38a1-pulp.lp
# Reading time = 0.08 seconds
# obj_tot: 27724 rows, 22685 columns, 56788 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 27724 rows, 22685 columns and 56788 nonzeros
# Model fingerprint: 0xb766b1c5
# Variable types: 15125 continuous, 7560 integer (7560 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 1e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 3e+08]
#   RHS range        [3e+00, 4e+06]
# Presolve removed 27724 rows and 22685 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.02 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1.77139e+08 1.77139e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.8918e-06) exceeds tolerance
# Best objective 1.771385645732e+08, best bound 1.771385645732e+08, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\27473ca41d764c8b92fd0a7d869f38a1-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : pv
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# 	Quantity : power_curve
# 	Quantity : nb_unit
# Updating unit : conso
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Optimization Scenario 1 completed, results saved to ./data/France_results.csv
# Data loaded from ./data/Czech_dataset.csv , Starting Optimization Scenario 1 for Czech
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# Creating the pv.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\energy_units.py:1429: UserWarning: The solution may be imaginary as nb_unit is continuous
#   warnings.warn(
# Creating the conso.
# Creating the grid_imp.
# Creating the grid_exp.
# Creating the elec_node.
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\b6a2a8a0258e4883ab689b105903a492-pulp.lp
# Reading time = 0.07 seconds
# obj_tot: 27724 rows, 22685 columns, 56809 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 27724 rows, 22685 columns and 56809 nonzeros
# Model fingerprint: 0xdffcb438
# Variable types: 15125 continuous, 7560 integer (7560 binary)
# Coefficient statistics:
#   Matrix range     [5e-07, 1e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 3e+08]
#   RHS range        [3e+00, 4e+06]
# Presolve removed 27724 rows and 22685 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1.68778e+09 1.68778e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.2589e-06) exceeds tolerance
# Warning: max bound violation (7.2775e-06) exceeds tolerance
# Best objective 1.687783695902e+09, best bound 1.687783695902e+09, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\b6a2a8a0258e4883ab689b105903a492-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : pv
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# 	Quantity : power_curve
# 	Quantity : nb_unit
# Updating unit : conso
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Optimization Scenario 1 completed, results saved to ./data/Czech_results.csv
# 0

# %%
process = subprocess.Popen(
    ["python", "Scenario_2_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="")

process.wait()
# Out:
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# Data loaded from ./data/France_results.csv , Starting Optimization Scenario 2 for France
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# Creating the elec_node.
# Creating the consumption_block_0.
# emax : 789.9999999999989
# Creating the consumption_block_1.
# emax : 7724.999999999994
# Creating the consumption_block_2.
# emax : 166195.0
# Creating the consumption_block_3.
# emax : 278086.6666666667
# Creating the consumption_block_4.
# emax : 210635.0
# Creating the consumption_block_5.
# emax : 147931.66666666666
# Creating the consumption_block_6.
# emax : 443166.0
# Creating the consumption_block_7.
# emax : 353867.8333333333
# Creating the consumption_block_8.
# emax : 157560.3333333333
# Creating the consumption_block_9.
# emax : 312502.3333333333
# Creating the consumption_block_10.
# emax : 284934.5
# Creating the consumption_block_11.
# emax : 234061.66666666666
# Creating the consumption_block_12.
# emax : 268586.8333333333
# Creating the consumption_block_13.
# emax : 142885.8333333333
# Creating the consumption_block_14.
# emax : 582988.8333333333
# Creating the consumption_block_15.
# emax : 407344.5
# Creating the pv.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\energy_units.py:1429: UserWarning: The solution may be imaginary as nb_unit is continuous
#   warnings.warn(
# Creating the grid_imp.
# Creating the grid_exp.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit elec_node seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
# READY TO SOLVE
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\cb1987ca737e49408d729f91fabb1f7d-pulp.lp
# Reading time = 7.26 seconds
# obj_tot: 70627 rows, 103340 columns, 6384488 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 70627 rows, 103340 columns and 6384488 nonzeros
# Model fingerprint: 0xb2b12c3d
# Variable types: 55460 continuous, 47880 integer (47880 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 1e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 3e+08]
#   RHS range        [1e+00, 6e+05]
# Presolve removed 65934 rows and 97094 columns
# Presolve time: 1.81s
# Presolved: 4693 rows, 6246 columns, 52224 nonzeros
# Variable types: 5889 continuous, 357 integer (256 binary)
# Found heuristic solution: objective 1.930494e+08
# Performing another presolve...
# Presolve removed 2920 rows and 2996 columns
# Presolve time: 0.29s
#
# Root relaxation: objective 1.496667e+08, 2430 iterations, 0.13 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.496667e+08 1.4967e+08  0.00%     -    3s
#
# Explored 1 nodes (2430 simplex iterations) in 3.95 seconds (2.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.49667e+08 1.93049e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.496667161249e+08, best bound 1.496667161249e+08, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\cb1987ca737e49408d729f91fabb1f7d-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : consumption_block_0
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_1
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_2
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_3
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_4
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_5
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_6
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_7
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_8
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_9
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_10
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_11
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_12
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_13
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_14
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_15
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : pv
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# 	Quantity : power_curve
# 	Quantity : nb_unit
# Optimization Scenario 2 completed, results saved to ./data/France_results.csv
# Data loaded from ./data/Czech_results.csv , Starting Optimization Scenario 2 for Czech
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# Creating the elec_node.
# Creating the consumption_block_0.
# emax : 789.9999999999989
# Creating the consumption_block_1.
# emax : 7724.999999999994
# Creating the consumption_block_2.
# emax : 166195.0
# Creating the consumption_block_3.
# emax : 278086.6666666667
# Creating the consumption_block_4.
# emax : 210635.0
# Creating the consumption_block_5.
# emax : 147931.66666666666
# Creating the consumption_block_6.
# emax : 443166.0
# Creating the consumption_block_7.
# emax : 353867.8333333333
# Creating the consumption_block_8.
# emax : 157560.3333333333
# Creating the consumption_block_9.
# emax : 312502.3333333333
# Creating the consumption_block_10.
# emax : 284934.5
# Creating the consumption_block_11.
# emax : 234061.66666666666
# Creating the consumption_block_12.
# emax : 268586.8333333333
# Creating the consumption_block_13.
# emax : 142885.8333333333
# Creating the consumption_block_14.
# emax : 582988.8333333333
# Creating the consumption_block_15.
# emax : 407344.5
# Creating the pv.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\energy_units.py:1429: UserWarning: The solution may be imaginary as nb_unit is continuous
#   warnings.warn(
# Creating the grid_imp.
# Creating the grid_exp.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit elec_node seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
# READY TO SOLVE
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\20b4dc0ec32343ffb1638ebcb7c39ee9-pulp.lp
# Reading time = 6.73 seconds
# obj_tot: 70627 rows, 103340 columns, 6384509 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 70627 rows, 103340 columns and 6384509 nonzeros
# Model fingerprint: 0x9e67a9c3
# Variable types: 55460 continuous, 47880 integer (47880 binary)
# Coefficient statistics:
#   Matrix range     [5e-07, 1e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 3e

#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 11
#   MIR: 36
#   Flow cover: 1
#   RLT: 22
#
# Explored 22814 nodes (1072232 simplex iterations) in 71.10 seconds (68.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1.51276e+09 1.51276e+09 1.52915e+09 ... 1.76569e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.512761551457e+09, best bound 1.512761551457e+09, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\20b4dc0ec32343ffb1638ebcb7c39ee9-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : consumption_block_0
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_1
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_2
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_3
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_4
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_5
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_6
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_7
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_8
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_9
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_10
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_11
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_12
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_13
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_14
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_15
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : pv
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# 	Quantity : power_curve
# 	Quantity : nb_unit
# Optimization Scenario 2 completed, results saved to ./data/Czech_results.csv
# 0

# %%
process = subprocess.Popen(
    ["python", "Scenario_3_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout: 
    print(line, end="")

process.wait()
# Out:
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# Data loaded from ./data/France_results.csv , Starting Optimization Scenario 4 for France
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_3_article.py:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_3_article.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# Creating the elec_node.
# Creating the heat_node_1.
# Creating the heat_node_2.
# Creating the consumption_block_0_therm_prod.
# Creating the consumption_block_0_elec_cons.
# emax : 789.9999999999989
# Creating the consumption_block_0.
# Creating the consumption_block_1_therm_prod.
# Creating the consumption_block_1_elec_cons.
# emax : 7724.999999999994
# Creating the consumption_block_1.
# Creating the consumption_block_2_therm_prod.
# Creating the consumption_block_2_elec_cons.
# emax : 166195.0
# Creating the consumption_block_2.
# Creating the consumption_block_3_therm_prod.
# Creating the consumption_block_3_elec_cons.
# emax : 278086.6666666667
# Creating the consumption_block_3.
# Creating the consumption_block_4_therm_prod.
# Creating the consumption_block_4_elec_cons.
# emax : 210635.0
# Creating the consumption_block_4.
# Creating the consumption_block_5_therm_prod.
# Creating the consumption_block_5_elec_cons.
# emax : 147931.66666666666
# Creating the consumption_block_5.
# Creating the consumption_block_6_therm_prod.
# Creating the consumption_block_6_elec_cons.
# emax : 443166.0
# Creating the consumption_block_6.
# Creating the consumption_block_7_therm_prod.
# Creating the consumption_block_7_elec_cons.
# emax : 353867.8333333333
# Creating the consumption_block_7.
# Creating the consumption_block_8_therm_prod.
# Creating the consumption_block_8_elec_cons.
# emax : 157560.3333333333
# Creating the consumption_block_8.
# Creating the consumption_block_9_therm_prod.
# Creating the consumption_block_9_elec_cons.
# emax : 312502.3333333333
# Creating the consumption_block_9.
# Creating the consumption_block_10_therm_prod.
# Creating the consumption_block_10_elec_cons.
# emax : 284934.5
# Creating the consumption_block_10.
# Creating the consumption_block_11_therm_prod.
# Creating the consumption_block_11_elec_cons.
# emax : 234061.66666666666
# Creating the consumption_block_11.
# Creating the consumption_block_12_therm_prod.
# Creating the consumption_block_12_elec_cons.
# emax : 268586.8333333333
# Creating the consumption_block_12.
# Creating the consumption_block_13_therm_prod.
# Creating the consumption_block_13_elec_cons.
# emax : 142885.8333333333
# Creating the consumption_block_13.
# Creating the consumption_block_14_therm_prod.
# Creating the consumption_block_14_elec_cons.
# emax : 582988.8333333333
# Creating the consumption_block_14.
# Creating the consumption_block_15_therm_prod.
# Creating the consumption_block_15_elec_cons.
# emax : 407344.5
# Creating the consumption_block_15.
# Creating the grid_imp.
# Creating the grid_exp.
# Creating the district_heat.
# Creating the heat_storage_discharge.
# Creating the heat_storage_charge.
# Creating the heat_storage.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\storage_units.py:205: UserWarning: If you are not using minimize_capacity, the capacity value should be defined
#   warnings.warn("If you are not using minimize_capacity, "
# Creating the heat_dissipation.
# Creating the CNRS_heat.
# Creating the heat_pump_therm_prod.
# Creating the heat_pump_therm_cons.
# Creating the heat_pump_elec_cons.
# Creating the heat_pump.
# Creating the surplus_consumption_therm_prod.
# Creating the surplus_consumption_elec_cons.
# Creating the surplus_consumption.
# ---------------------------------------------------------------------------------------
# pc_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
# pd_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit elec_node seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_0 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_3 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_4 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_5 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_6 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_7 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_8 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_9 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_10 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_11 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_12 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_13 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_14 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_15 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
# READY TO SOLVE
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\a62b4dbffd7f4acb944fe3db09e4abfd-pulp.lp
# Reading time = 9.06 seconds
# obj_tot: 186577 rows, 196609 columns, 6757504 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 186577 rows, 196609 columns and 6757504 nonzeros
# Model fingerprint: 0xbbe7df09
# Variable types: 138649 continuous, 57960 integer (57960 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+09]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 3e+12]
#   RHS range        [1e-02, 7e+05]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 157835 rows and 177739 columns
# Presolve time: 2.04s
# Presolved: 28742 rows, 18870 columns, 167307 nonzeros
# Variable types: 15993 continuous, 2877 integer (2776 binary)
# Found heuristic solution: objective 2.693666e+08
# Found heuristic solution: objective 2.662821e+08
# Performing another presolve...
# Presolve removed 10632 rows and 7840 columns
# Presolve time: 0.86s
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3039224e+07   1.960000e+03   0.000000e+00      5s
#      762    2.1703601e+08   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 2.170360e+08, 762 iterations, 0.13 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.170360e+08 2.1704e+08  0.00%     -    5s
#
# Explored 1 nodes (762 simplex iterations) in 5.47 seconds (3.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2.17036e+08 2.17036e+08 2.66282e+08 2.69367e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.170360142747e+08, best bound 2.170360142747e+08, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\a62b4dbffd7f4acb944fe3db09e4abfd-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : consumption_block_0_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_1_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_2_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_3_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_4_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_5_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_6_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_7_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_8_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_9_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_10_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_11_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_12_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_13_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_14_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_15_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# 	Quantity : total_consumption_magnets
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# Updating unit : surplus_consumption_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_pump_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : consumption_block_0
# Updating unit : consumption_block_1
# Updating unit : consumption_block_2
# Updating unit : consumption_block_3
# Updating unit : consumption_block_4
# Updating unit : consumption_block_5
# Updating unit : consumption_block_6
# Updating unit : consumption_block_7
# Updating unit : consumption_block_8
# Updating unit : consumption_block_9
# Updating unit : consumption_block_10
# Updating unit : consumption_block_11
# Updating unit : consumption_block_12
# Updating unit : consumption_block_13
# Updating unit : consumption_block_14
# Updating unit : consumption_block_15
# Updating unit : surplus_consumption
# Updating unit : heat_pump
# 	Quantity : COP
# Updating unit : consumption_block_0_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_1_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_2_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_3_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_4_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_5_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_6_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_7_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_8_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_9_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_10_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_11_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_12_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_13_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_14_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_15_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : surplus_consumption_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_pump_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_pump_therm_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_node_1
# 	Quantity : energy_export_to_heat_node_2
# 	Quantity : is_exporting_to_heat_node_2
# Updating unit : heat_dissipation
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_storage_charge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage_discharge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage
# 	Quantity : capacity
# 	Quantity : e
# 	Quantity : u
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : pc_max
# 	Quantity : pd_max
# 	Quantity : e_f
# Updating unit : heat_node_2
# 	Quantity : energy_export_to_heat_node_1
# 	Quantity : is_exporting_to_heat_node_1
# Updating unit : CNRS_heat
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : district_heat
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : operating_cost
# 	Quantity : co2_emissions
# Optimization Scenario 3 test completed, results saved to ./data/France_results.csv
# Data loaded from ./data/Czech_results.csv , Starting Optimization Scenario 4 for Czech
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_3_article.py:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_3_article.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# Creating the elec_node.
# Creating the heat_node_1.
# Creating the heat_node_2.
# Creating the consumption_block_0_therm_prod.
# Creating the consumption_block_0_elec_cons.
# emax : 789.9999999999989
# Creating the consumption_block_0.
# Creating the consumption_block_1_therm_prod.
# Creating the consumption_block_1_elec_cons.
# emax : 7724.999999999994
# Creating the consumption_block_1.
# Creating the consumption_block_2_therm_prod.
# Creating the consumption_block_2_elec_cons.
# emax : 166195.0
# Creating the consumption_block_2.
# Creating the consumption_block_3_therm_prod.
# Creating the consumption_block_3_elec_cons.
# emax : 278086.6666666667
# Creating the consumption_block_3.
# Creating the consumption_block_4_therm_prod.
# Creating the consumption_block_4_elec_cons.
# emax : 210635.0
# Creating the consumption_block_4.
# Creating the consumption_block_5_therm_prod.
# Creating the consumption_block_5_elec_cons.
# emax : 147931.66666666666
# Creating the consumption_block_5.
# Creating the consumption_block_6_therm_prod.
# Creating the consumption_block_6_elec_cons.
# emax : 443166.0
# Creating the consumption_block_6.
# Creating the consumption_block_7_therm_prod.
# Creating the consumption_block_7_elec_cons.
# emax : 353867.8333333333
# Creating the consumption_block_7.
# Creating the consumption_block_8_therm_prod.
# Creating the consumption_block_8_elec_cons.
# emax : 157560.3333333333
# Creating the consumption_block_8.
# Creating the consumption_block_9_therm_prod.
# Creating the consumption_block_9_elec_cons.
# emax : 312502.3333333333
# Creating the consumption_block_9.
# Creating the consumption_block_10_therm_prod.
# Creating the consumption_block_10_elec_cons.
# emax : 284934.5
# Creating the consumption_block_10.
# Creating the consumption_block_11_therm_prod.
# Creating the consumption_block_11_elec_cons.
# emax : 234061.66666666666
# Creating the consumption_block_11.
# Creating the consumption_block_12_therm_prod.
# Creating the consumption_block_12_elec_cons.
# emax : 268586.8333333333
# Creating the consumption_block_12.
# Creating the consumption_block_13_therm_prod.
# Creating the consumption_block_13_elec_cons.
# emax : 142885.8333333333
# Creating the consumption_block_13.
# Creating the consumption_block_14_therm_prod.
# Creating the consumption_block_14_elec_cons.
# emax : 582988.8333333333
# Creating the consumption_block_14.
# Creating the consumption_block_15_therm_prod.
# Creating the consumption_block_15_elec_cons.
# emax : 407344.5
# Creating the consumption_block_15.
# Creating the grid_imp.
# Creating the grid_exp.
# Creating the district_heat.
# Creating the heat_storage_discharge.
# Creating the heat_storage_charge.
# Creating the heat_storage.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\storage_units.py:205: UserWarning: If you are not using minimize_capacity, the capacity value should be defined
#   warnings.warn("If you are not using minimize_capacity, "
# Creating the heat_dissipation.
# Creating the CNRS_heat.
# Creating the heat_pump_therm_prod.
# Creating the heat_pump_therm_cons.
# Creating the heat_pump_elec_cons.
# Creating the heat_pump.
# Creating the surplus_consumption_therm_prod.
# Creating the surplus_consumption_elec_cons.
# Creating the surplus_consumption.
# ---------------------------------------------------------------------------------------
# pc_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
# pd_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit elec_node seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_0 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_3 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_4 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_5 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_6 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_7 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_8 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_9 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_10 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_11 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_12 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_13 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_14 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_15 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
# READY TO SOLVE
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\61f558dc4c1643b3b697876dd12aceb6-pulp.lp
# Reading time = 7.57 seconds
# obj_tot: 186577 rows, 196609 columns, 6757504 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 186577 rows, 196609 columns and 6757504 nonzeros
# Model fingerprint: 0xfe6d8585
# Variable types: 138649 continuous, 57960 integer (57960 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+09]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 3e+12]
#   RHS range        [1e-02, 7e+05]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large bounds
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 157835 rows and 177739 columns
# Presolve time: 1.68s
# Presolved: 28742 rows, 18870 columns, 167307 nonzeros
# Variable types: 15993 continuous, 2877 integer (2776 binary)
# Found heuristic solution: objective 2.141522e+09
# Found heuristic solution: objective 2.090393e+09
# Performing another presolve...
# Presolve removed 10632 rows and 7840 columns
# Presolve time: 1.00s
#
# Root relaxation: objective 1.947765e+09, 859 iterations, 0.16 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.947765e+09 1.9478e+09  0.00%     -    4s
#
# Explored 1 nodes (859 simplex iterations) in 4.61 seconds (3.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1.94776e+09 1.94776e+09 2.09039e+09 2.14152e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.947764958140e+09, best bound 1.947764958140e+09, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\61f558dc4c1643b3b697876dd12aceb6-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : consumption_block_0_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_1_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_2_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_3_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_4_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_5_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_6_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_7_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_8_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_9_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_10_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_11_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_12_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_13_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_14_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_15_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# 	Quantity : total_consumption_magnets
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# Updating unit : surplus_consumption_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_pump_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : consumption_block_0
# Updating unit : consumption_block_1
# Updating unit : consumption_block_2
# Updating unit : consumption_block_3
# Updating unit : consumption_block_4
# Updating unit : consumption_block_5
# Updating unit : consumption_block_6
# Updating unit : consumption_block_7
# Updating unit : consumption_block_8
# Updating unit : consumption_block_9
# Updating unit : consumption_block_10
# Updating unit : consumption_block_11
# Updating unit : consumption_block_12
# Updating unit : consumption_block_13
# Updating unit : consumption_block_14
# Updating unit : consumption_block_15
# Updating unit : surplus_consumption
# Updating unit : heat_pump
# 	Quantity : COP
# Updating unit : consumption_block_0_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_1_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_2_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_3_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_4_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_5_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_6_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_7_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_8_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_9_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_10_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_11_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_12_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_13_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_14_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_15_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : surplus_consumption_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_pump_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_pump_therm_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_node_1
# 	Quantity : energy_export_to_heat_node_2
# 	Quantity : is_exporting_to_heat_node_2
# Updating unit : heat_dissipation
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_storage_charge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage_discharge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage
# 	Quantity : capacity
# 	Quantity : e
# 	Quantity : u
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : pc_max
# 	Quantity : pd_max
# 	Quantity : e_f
# Updating unit : heat_node_2
# 	Quantity : energy_export_to_heat_node_1
# 	Quantity : is_exporting_to_heat_node_1
# Updating unit : CNRS_heat
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : district_heat
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : operating_cost
# 	Quantity : co2_emissions
# Optimization Scenario 3 test completed, results saved to ./data/Czech_results.csv
# 0

# %%
process = subprocess.Popen(
    ["python", "Scenario_4_article.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)
for line in process.stdout:
    print(line, end="")

process.wait()
# Out:
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# DEPRECATED: please now use SingleConversionUnit with relevant energytypes
# Data loaded from ./data/France_results.csv , Starting Optimization Scenario 4 for France
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# new column: heat_demand_district_heat_S3_MW[kW]
# new column: heat_demand_district_heat_S4_MW[kW]
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_4_article.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_4_article.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# Creating the elec_node.
# Creating the heat_node_1.
# Creating the heat_node_2.
# Creating the consumption_block_0_therm_prod.
# Creating the consumption_block_0_elec_cons.
# emax : 789.9999999999989
# Creating the consumption_block_0.
# Creating the consumption_block_1_therm_prod.
# Creating the consumption_block_1_elec_cons.
# emax : 7724.999999999994
# Creating the consumption_block_1.
# Creating the consumption_block_2_therm_prod.
# Creating the consumption_block_2_elec_cons.
# emax : 166195.0
# Creating the consumption_block_2.
# Creating the consumption_block_3_therm_prod.
# Creating the consumption_block_3_elec_cons.
# emax : 278086.6666666667
# Creating the consumption_block_3.
# Creating the consumption_block_4_therm_prod.
# Creating the consumption_block_4_elec_cons.
# emax : 210635.0
# Creating the consumption_block_4.
# Creating the consumption_block_5_therm_prod.
# Creating the consumption_block_5_elec_cons.
# emax : 147931.66666666666
# Creating the consumption_block_5.
# Creating the consumption_block_6_therm_prod.
# Creating the consumption_block_6_elec_cons.
# emax : 443166.0
# Creating the consumption_block_6.
# Creating the consumption_block_7_therm_prod.
# Creating the consumption_block_7_elec_cons.
# emax : 353867.8333333333
# Creating the consumption_block_7.
# Creating the consumption_block_8_therm_prod.
# Creating the consumption_block_8_elec_cons.
# emax : 157560.3333333333
# Creating the consumption_block_8.
# Creating the consumption_block_9_therm_prod.
# Creating the consumption_block_9_elec_cons.
# emax : 312502.3333333333
# Creating the consumption_block_9.
# Creating the consumption_block_10_therm_prod.
# Creating the consumption_block_10_elec_cons.
# emax : 284934.5
# Creating the consumption_block_10.
# Creating the consumption_block_11_therm_prod.
# Creating the consumption_block_11_elec_cons.
# emax : 234061.66666666666
# Creating the consumption_block_11.
# Creating the consumption_block_12_therm_prod.
# Creating the consumption_block_12_elec_cons.
# emax : 268586.8333333333
# Creating the consumption_block_12.
# Creating the consumption_block_13_therm_prod.
# Creating the consumption_block_13_elec_cons.
# emax : 142885.8333333333
# Creating the consumption_block_13.
# Creating the consumption_block_14_therm_prod.
# Creating the consumption_block_14_elec_cons.
# emax : 582988.8333333333
# Creating the consumption_block_14.
# Creating the consumption_block_15_therm_prod.
# Creating the consumption_block_15_elec_cons.
# emax : 407344.5
# Creating the consumption_block_15.
# Creating the pv.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\energy_units.py:1429: UserWarning: The solution may be imaginary as nb_unit is continuous
#   warnings.warn(
# Creating the grid_imp.
# Creating the grid_exp.
# Creating the district_heat.
# Creating the heat_storage_discharge.
# Creating the heat_storage_charge.
# Creating the heat_storage.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\storage_units.py:205: UserWarning: If you are not using minimize_capacity, the capacity value should be defined
#   warnings.warn("If you are not using minimize_capacity, "
# Creating the heat_dissipation.
# Creating the CNRS_heat.
# Creating the heat_pump_therm_prod.
# Creating the heat_pump_therm_cons.
# Creating the heat_pump_elec_cons.
# Creating the heat_pump.
# Creating the surplus_consumption_therm_prod.
# Creating the surplus_consumption_elec_cons.
# Creating the surplus_consumption.
# ---------------------------------------------------------------------------------------
# pc_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
# pd_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit elec_node seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_0 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_3 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_4 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_5 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_6 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_7 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_8 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_9 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_10 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_11 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_12 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_13 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_14 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_15 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
# READY TO SOLVE
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\be10b02b914049ea8bac3152fa6fce19-pulp.lp
# Reading time = 11.46 seconds
# obj_tot: 196658 rows, 204171 columns, 6776489 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 196658 rows, 204171 columns and 6776489 nonzeros
# Model fingerprint: 0x3ff663ce
# Variable types: 143691 continuous, 60480 integer (60480 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 1e+09]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+00, 3e+12]
#   RHS range        [1e-02, 7e+05]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large bounds
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 167916 rows and 183956 columns
# Presolve time: 2.26s
# Presolved: 28742 rows, 20215 columns, 169995 nonzeros
# Variable types: 17338 continuous, 2877 integer (2776 binary)
# Found heuristic solution: objective 2.756107e+08
# Found heuristic solution: objective 2.720885e+08
# Found heuristic solution: objective 2.662821e+08
# Performing another presolve...
# Presolve removed 9224 rows and 6537 columns
# Presolve time: 1.15s
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3083806e+07   2.041875e+02   9.365522e+06      6s
#       81    3.9609001e+09   0.000000e+00   1.164788e+07      6s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3315    2.1703601e+08   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 2.170360e+08, 3315 iterations, 0.70 seconds (0.39 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.170360e+08 2.1704e+08  0.00%     -    6s
#
# Explored 1 nodes (3315 simplex iterations) in 7.18 seconds (3.55 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 2.17036e+08 2.17036e+08 2.66282e+08 ... 2.75611e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.170360142748e+08, best bound 2.170360142748e+08, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\be10b02b914049ea8bac3152fa6fce19-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : consumption_block_0_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_1_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_2_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_3_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_4_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_5_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_6_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_7_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_8_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_9_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_10_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_11_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_12_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_13_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_14_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_15_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# 	Quantity : total_consumption_magnets
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# Updating unit : surplus_consumption_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_pump_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : pv
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# 	Quantity : power_curve
# 	Quantity : nb_unit
# Updating unit : consumption_block_0
# Updating unit : consumption_block_1
# Updating unit : consumption_block_2
# Updating unit : consumption_block_3
# Updating unit : consumption_block_4
# Updating unit : consumption_block_5
# Updating unit : consumption_block_6
# Updating unit : consumption_block_7
# Updating unit : consumption_block_8
# Updating unit : consumption_block_9
# Updating unit : consumption_block_10
# Updating unit : consumption_block_11
# Updating unit : consumption_block_12
# Updating unit : consumption_block_13
# Updating unit : consumption_block_14
# Updating unit : consumption_block_15
# Updating unit : surplus_consumption
# Updating unit : heat_pump
# 	Quantity : COP
# Updating unit : consumption_block_0_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_1_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_2_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_3_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_4_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_5_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_6_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_7_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_8_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_9_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_10_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_11_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_12_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_13_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_14_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_15_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : surplus_consumption_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_pump_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_pump_therm_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_node_1
# 	Quantity : energy_export_to_heat_node_2
# 	Quantity : is_exporting_to_heat_node_2
# Updating unit : heat_dissipation
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_storage_charge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage_discharge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage
# 	Quantity : capacity
# 	Quantity : e
# 	Quantity : u
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : pc_max
# 	Quantity : pd_max
# 	Quantity : e_f
# Updating unit : heat_node_2
# 	Quantity : energy_export_to_heat_node_1
# 	Quantity : is_exporting_to_heat_node_1
# Updating unit : CNRS_heat
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : district_heat
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : operating_cost
# 	Quantity : co2_emissions
# Optimization Scenario 4 completed, results saved to ./data/France_results.csv
# Data loaded from ./data/Czech_results.csv , Starting Optimization Scenario 4 for Czech
# new column: Electricity_Consumption[kW]
# new column: Heat_demand[kW]
# new column: heat_demand_district_heat_S3_MW[kW]
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_4_article.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# c:\Users\twumduan\My_Files\PycharmProjects\flexrican_github\FlexRICAN\WP6_Flexibility\Notebooks\lncmi\flexibility_interactions_REST_Article\Scenario_4_article.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp ["valorize"].loc[temp['Heat_demand[kW]']> 0.0001] = 1
# You are studying the period from 2023-01-01 00:00:00 to 2023-04-15 23:00:00
# Creating the elec_node.
# Creating the heat_node_1.
# Creating the heat_node_2.
# Creating the consumption_block_0_therm_prod.
# Creating the consumption_block_0_elec_cons.
# emax : 789.9999999999989
# Creating the consumption_block_0.
# Creating the consumption_block_1_therm_prod.
# Creating the consumption_block_1_elec_cons.
# emax : 7724.999999999994
# Creating the consumption_block_1.
# Creating the consumption_block_2_therm_prod.
# Creating the consumption_block_2_elec_cons.
# emax : 166195.0
# Creating the consumption_block_2.
# Creating the consumption_block_3_therm_prod.
# Creating the consumption_block_3_elec_cons.
# emax : 278086.6666666667
# Creating the consumption_block_3.
# Creating the consumption_block_4_therm_prod.
# Creating the consumption_block_4_elec_cons.
# emax : 210635.0
# Creating the consumption_block_4.
# Creating the consumption_block_5_therm_prod.
# Creating the consumption_block_5_elec_cons.
# emax : 147931.66666666666
# Creating the consumption_block_5.
# Creating the consumption_block_6_therm_prod.
# Creating the consumption_block_6_elec_cons.
# emax : 443166.0
# Creating the consumption_block_6.
# Creating the consumption_block_7_therm_prod.
# Creating the consumption_block_7_elec_cons.
# emax : 353867.8333333333
# Creating the consumption_block_7.
# Creating the consumption_block_8_therm_prod.
# Creating the consumption_block_8_elec_cons.
# emax : 157560.3333333333
# Creating the consumption_block_8.
# Creating the consumption_block_9_therm_prod.
# Creating the consumption_block_9_elec_cons.
# emax : 312502.3333333333
# Creating the consumption_block_9.
# Creating the consumption_block_10_therm_prod.
# Creating the consumption_block_10_elec_cons.
# emax : 284934.5
# Creating the consumption_block_10.
# Creating the consumption_block_11_therm_prod.
# Creating the consumption_block_11_elec_cons.
# emax : 234061.66666666666
# Creating the consumption_block_11.
# Creating the consumption_block_12_therm_prod.
# Creating the consumption_block_12_elec_cons.
# emax : 268586.8333333333
# Creating the consumption_block_12.
# Creating the consumption_block_13_therm_prod.
# Creating the consumption_block_13_elec_cons.
# emax : 142885.8333333333
# Creating the consumption_block_13.
# Creating the consumption_block_14_therm_prod.
# Creating the consumption_block_14_elec_cons.
# emax : 582988.8333333333
# Creating the consumption_block_14.
# Creating the consumption_block_15_therm_prod.
# Creating the consumption_block_15_elec_cons.
# emax : 407344.5
# Creating the consumption_block_15.
# Creating the pv.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\energy_units.py:1429: UserWarning: The solution may be imaginary as nb_unit is continuous
#   warnings.warn(
# Creating the grid_imp.
# Creating the grid_exp.
# Creating the district_heat.
# Creating the heat_storage_discharge.
# Creating the heat_storage_charge.
# Creating the heat_storage.
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\energy\units\storage_units.py:205: UserWarning: If you are not using minimize_capacity, the capacity value should be defined
#   warnings.warn("If you are not using minimize_capacity, "
# Creating the heat_dissipation.
# Creating the CNRS_heat.
# Creating the heat_pump_therm_prod.
# Creating the heat_pump_therm_cons.
# Creating the heat_pump_elec_cons.
# Creating the heat_pump.
# Creating the surplus_consumption_therm_prod.
# Creating the surplus_consumption_elec_cons.
# Creating the surplus_consumption.
# ---------------------------------------------------------------------------------------
# pc_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
# pd_max_ratio is not defined: the maximum charging power is set to the value of the capacity
# ---------------------------------------------------------------------------------------
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit elec_node seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_0 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_3 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_4 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_5 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_6 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_7 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_8 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_9 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_10 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_11 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_12 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_13 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_14 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:603: UserWarning: The unit consumption_block_15 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_1 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
# c:\Users\twumduan\AppData\Local\anaconda3\Lib\site-packages\omegalpes\general\optimisation\model.py:591: UserWarning: The unit heat_node_2 seems to have as parent consumption_block_15 which was not declared as parent.
#   warnings.warn('The unit {} seems to have as parent {} '
#
# --- Adding all variables to the model ---
#
# --- Adding all objectives to the model ---
#
# --- Adding all constraints to the model ---
# READY TO SOLVE
#
#  - - - - - RUN OPTIMIZATION - - - - -
# Set parameter Username
# Set parameter LicenseID to value 2737477
# Set parameter LogFile to value "gurobi.log"
# Using license file C:\Users\twumduan\gurobi.lic
# Academic license - for non-commercial use only - expires 2026-11-13
#
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11+.0 (26200.2))
# Copyright (c) 2025, Gurobi Optimization, LLC
#
# Read LP format model from file C:\Users\twumduan\AppData\Local\Temp\849d9e99b9c34eb9830df3f7b6ecb884-pulp.lp
# Reading time = 10.74 seconds
# obj_tot: 196658 rows, 204171 columns, 6776510 nonzeros
#
# Using Gurobi shared library C:\gurobi1201\win64\bin\gurobi120.dll
#
# CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 196658 rows, 204171 columns and 6776510 nonzeros
# Model fingerprint: 0x395bbbb6
# Variable types: 143691 continuous, 60480 integer (60480 binary)
# Coefficient statistics:
#   Matrix range     [5e-07, 1e+09]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+00, 3e+12]
#   RHS range        [1e-02, 7e+05]
# Warning: Model contains large matrix coefficient range
# Warning: Model contains large bounds
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 167915 rows and 183934 columns
# Presolve time: 2.25s
# Presolved: 28743 rows, 20237 columns, 170039 nonzeros
# Variable types: 17360 continuous, 2877 integer (2776 binary)
# Found heuristic solution: objective 1.853165e+09
# Performing another presolve...
# Presolve removed 9208 rows and 6526 columns
# Presolve time: 1.35s
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3087081e+07   2.055703e+02   6.994749e+06      6s
#       95    3.4217300e+10   0.000000e+00   4.954360e+07      6s
#     2466    1.4952632e+09   0.000000e+00   0.000000e+00      7s
# Concurrent spin time: 0.16s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#     2466    1.4952632e+09   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 1.495263e+09, 2466 iterations, 1.13 seconds (0.54 work units)
# Total elapsed time = 7.32s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.
#  26455   773 1.6003e+09   40  155 1.6097e+09 1.5977e+09  0.75%   361 1120s
#  26823   562 infeasible   53      1.6097e+09 1.5986e+09  0.69%   362 1131s
#  27300   313 1.6051e+09   25  466 1.6097e+09 1.5998e+09  0.62%   362 1143s
#  27712    37 infeasible   44      1.6097e+09 1.6015e+09  0.51%   363 1154s
#  28107     0     cutoff   54      1.6097e+09 1.6053e+09  0.27%   364 1155s
#
# Cutting planes:
#   Learned: 19
#   Gomory: 5
#   Implied bound: 15
#   MIR: 35
#   Flow cover: 13
#   RLT: 25
#
# Explored 28147 nodes (10237950 simplex iterations) in 1155.81 seconds (985.35 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.60972e+09 1.60972e+09 1.61155e+09 ... 1.85317e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max bound violation (2.8987e-06) exceeds tolerance
# Best objective 1.609719020705e+09, best bound 1.609719020705e+09, gap 0.0000%
#
# Wrote result file 'C:\Users\twumduan\AppData\Local\Temp\849d9e99b9c34eb9830df3f7b6ecb884-pulp.sol'
#
#
#  - - - - - UPDATE RESULTS - - - - -
# Updating unit : elec_node
# Updating unit : consumption_block_0_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_1_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_2_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_3_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_4_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_5_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_6_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_7_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_8_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_9_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_10_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_11_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_12_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_13_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_14_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : consumption_block_15_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : start_up
# 	Quantity : power_values
# Updating unit : grid_imp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# 	Quantity : total_consumption_magnets
# Updating unit : grid_exp
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : co2_emissions
# Updating unit : surplus_consumption_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_pump_elec_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : pv
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# 	Quantity : power_curve
# 	Quantity : nb_unit
# Updating unit : consumption_block_0
# Updating unit : consumption_block_1
# Updating unit : consumption_block_2
# Updating unit : consumption_block_3
# Updating unit : consumption_block_4
# Updating unit : consumption_block_5
# Updating unit : consumption_block_6
# Updating unit : consumption_block_7
# Updating unit : consumption_block_8
# Updating unit : consumption_block_9
# Updating unit : consumption_block_10
# Updating unit : consumption_block_11
# Updating unit : consumption_block_12
# Updating unit : consumption_block_13
# Updating unit : consumption_block_14
# Updating unit : consumption_block_15
# Updating unit : surplus_consumption
# Updating unit : heat_pump
# 	Quantity : COP
# Updating unit : consumption_block_0_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_1_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_2_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_3_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_4_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_5_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_6_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_7_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_8_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_9_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_10_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_11_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_12_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_13_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_14_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : consumption_block_15_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : surplus_consumption_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_pump_therm_prod
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_pump_therm_cons
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# Updating unit : heat_node_1
# 	Quantity : energy_export_to_heat_node_2
# 	Quantity : is_exporting_to_heat_node_2
# Updating unit : heat_dissipation
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : heat_storage_charge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage_discharge
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : u
# 	Quantity : co2_emissions
# Updating unit : heat_storage
# 	Quantity : capacity
# 	Quantity : e
# 	Quantity : u
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : pc_max
# 	Quantity : pd_max
# 	Quantity : e_f
# Updating unit : heat_node_2
# 	Quantity : energy_export_to_heat_node_1
# 	Quantity : is_exporting_to_heat_node_1
# Updating unit : CNRS_heat
# 	Quantity : p
# 	Quantity : e_tot
# Updating unit : district_heat
# 	Quantity : p
# 	Quantity : e_tot
# 	Quantity : operating_cost
# 	Quantity : co2_emissions
# Optimization Scenario 4 completed, results saved to ./data/Czech_results.csv
# 0
